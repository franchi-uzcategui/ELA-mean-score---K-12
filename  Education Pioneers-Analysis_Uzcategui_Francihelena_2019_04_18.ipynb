# %% [markdown]
# <h1>Project: 2019 Impact Fellowship-Education Pioneers. Investigate the ELA program Datasets 2016-2017</h1>
# <h3>Autor: Francihelena Uzcategui</h3>
#
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#cleaning">Data Cleaning</a></li>
# <li><a href="#eda">Exploratory Data Analysis </a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# <li><a href="#limitations">Limitations</a></li>
# </ul>
#
#
# <h3>Introduction </h3>
#
#  <p>The Education Pioneers datasets have univariate and bivariate data to analyze — relations between Education and Demographic indexes, and how they affect the growth and development of students. </p>
#
# <h5>Questions </h5>
#
# <h6>1- How did the pilot school 5th graders’ ELA mean scores compare to the non-pilot 5th graders in 2017 (2016 - 2017 school year)?</h6>
#         <p>1.1- What was the average score of all the pilot schools combined?</p>
#         <p>1.2- What was the average score of all the non-pilot schools combined?</p>.
# <h6>2- Which pilot school exhibited the most growth in ELA mean scale scores?</h6>
#         <p>2.1- Which pilot school exhibited the most growth in ELA mean scale scores from the 2016 test through the 2017 test</p>
#         <p>2.2- What is the percentage difference in this school’s 5th grade growth from 2016 through 2017 compared to the other pilot schools’ 5th grade average growth during the same time period?</p>
# <h6>3- What was the average percentage of students who received free/reduced lunch in the 5 pilot schools in 2017?</h6>
# <h6>4- What was the average ELA mean test score of the non-pilot schools that have an equal or greater percentage of students who qualify for free/reduced lunch as the pilot schools? Only look at the 5th grade class in the 2017 school year.</h6>

# %% [markdown]
# <h3> I Dataset </h3>

# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame, Panel
import matplotlib.pyplot as plt

# %% [markdown]
# <h6>Data Wrangling</h6>

# %%
df = pd.read_csv('C:/Users/Franchi/Desktop/data exercise1.csv')
df.head()
# Out:
#    School_ID  Year                Test Name # Students Tested  \
# 0     400009  2017  Combined ELA Grades 3-8               179
# 1     400011  2017  Combined ELA Grades 3-8               297
# 2     400017  2017  Combined ELA Grades 3-8               524
# 3     400021  2017  Combined ELA Grades 3-8               330
# 4     400023  2017  Combined ELA Grades 3-8               268
#
#   Overall_ELA_Mean_Scale_Score % Did Not Meet % Partially Met % Approached  \
# 0                                      19.00%          31.30%       22.90%
# 1                                       7.70%          12.10%       38.00%
# 2                                      35.90%          28.20%       24.00%
# 3                                      27.90%          27.00%       28.20%
# 4                                       9.30%          21.60%       32.10%
#
#     % Met % Exceeded         ...          \
# 0  26.30%      0.60%         ...
# 1  38.40%      3.70%         ...
# 2  10.90%      1.00%         ...
# 3  15.80%      1.20%         ...
# 4  33.20%      3.70%         ...
#
#   % Did Not Yet Meet or Partially Met.2 % Approached.3 % Met or Exceeded.3  \
# 0                                48.60%         22.30%              29.10%
# 1                                33.30%         24.90%              41.80%
# 2                                64.70%         18.50%              16.80%
# 3                                53.90%         24.20%              21.80%
# 4                                39.90%         29.10%              31.00%
#
#   Writing Mean Scale Score % Did Not Yet Meet or Partially Met.3  \
# 0                                                         53.10%
# 1                                                         28.60%
# 2                                                         67.90%
# 3                                                         65.50%
# 4                                                         34.00%
#
#   % Approached.4 % Met or Exceeded.4 % Did Not Yet Meet or Partially Met.4  \
# 0         25.10%              21.80%                                47.50%
# 1         24.60%              46.80%                                26.90%
# 2         16.60%              15.50%                                66.40%
# 3         17.00%              17.60%                                60.30%
# 4         19.80%              46.30%                                28.40%
#
#   % Approached.5 % Met or Exceeded.5
# 0         27.40%              25.10%
# 1         25.90%              47.10%
# 2         18.90%              14.70%
# 3         18.80%              20.90%
# 4         25.00%              46.60%
#
# [5 rows x 28 columns]

# %% [markdown]
# <h6>Data Cleaning</h6>

# %% [markdown]
# From the original csv file, we deleted the first row along all the columns to avoid issues at the moment of importing; it was 'unnamed.'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6762 entries, 0 to 6761
# Data columns (total 28 columns):
# School_ID                                6762 non-null int64
# Year                                     6762 non-null int64
# Test Name                                6762 non-null object
# # Students Tested                        6762 non-null object
# Overall_ELA_Mean_Scale_Score             6761 non-null object
# % Did Not Meet                           6762 non-null object
# % Partially Met                          6762 non-null object
# % Approached                             6762 non-null object
# % Met                                    6762 non-null object
# % Exceeded                               6762 non-null object
# % Met or Exceeded                        6762 non-null object
# Reading Mean Scale Score                 6762 non-null object
# % Did Not Yet Meet or Partially Met      6762 non-null object
# % Approached.1                           6762 non-null object
# % Met or Exceeded.1                      6762 non-null object
# % Did Not Yet Meet or Partially Met.1    6762 non-null object
# % Approached.2                           6762 non-null object
# % Met or Exceeded.2                      6762 non-null object
# % Did Not Yet Meet or Partially Met.2    6762 non-null object
# % Approached.3                           6762 non-null object
# % Met or Exceeded.3                      6762 non-null object
# Writing Mean Scale Score                 6762 non-null object
# % Did Not Yet Meet or Partially Met.3    6762 non-null object
# % Approached.4                           6762 non-null object
# % Met or Exceeded.4                      6762 non-null object
# % Did Not Yet Meet or Partially Met.4    6762 non-null object
# % Approached.5                           6762 non-null object
# % Met or Exceeded.5                      6762 non-null object
# dtypes: int64(2), object(26)
# memory usage: 1.4+ MB

# %%
df.dtypes
# Out:
# School_ID                                 int64
# Year                                      int64
# Test Name                                object
# # Students Tested                        object
# Overall_ELA_Mean_Scale_Score             object
# % Did Not Meet                           object
# % Partially Met                          object
# % Approached                             object
# % Met                                    object
# % Exceeded                               object
# % Met or Exceeded                        object
# Reading Mean Scale Score                 object
# % Did Not Yet Meet or Partially Met      object
# % Approached.1                           object
# % Met or Exceeded.1                      object
# % Did Not Yet Meet or Partially Met.1    object
# % Approached.2                           object
# % Met or Exceeded.2                      object
# % Did Not Yet Meet or Partially Met.2    object
# % Approached.3                           object
# % Met or Exceeded.3                      object
# Writing Mean Scale Score                 object
# % Did Not Yet Meet or Partially Met.3    object
# % Approached.4                           object
# % Met or Exceeded.4                      object
# % Did Not Yet Meet or Partially Met.4    object
# % Approached.5                           object
# % Met or Exceeded.5                      object
# dtype: object

# %% [markdown]
# Changing Overall_ELA_Mean_Scale_Score str to int. After too many fail attemps the solution includes two steps.
# First to fill the empty rows with 0 (ValueError: invalid literal for int() with base 10 '').
# Second directly we transformed str to int.
# Source:https://www.ritchieng.com/pandas-changing-datatype/, https://stackoverflow.com/questions/25586085/replace-whitespace-with-a-0-in-pandas-python-3, https://stackoverflow.com/questions/10591000/specifying-data-type-in-pandas-csv-reader?fbclid=IwAR2qm41ZUc8su98ftOUtS-aDYpaUxdBhAVk616p6T3xajgUh9UhovBA01c4

# %% [markdown]
# Changing data type by .to_numeric()
# "Pandas operations like to_numeric don't operate "in-place" by default. I recommend that you assign the result to a column in your dataframe.
# df['Period_numbers'] = pd.to_numeric(df['Period'], errors='coerce') Same goes with dropna.
# In most cases you can pass inplace=True to the method or function. But I really do recommend assigning the results instead"
#
# Source:https://stackoverflow.com/questions/40493726/pd-to-numeric-is-not-working-in-python

# %%
df['Overall_ELA_Mean_Scale_Score_numbers'] = pd.to_numeric(df['Overall_ELA_Mean_Scale_Score'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6762 entries, 0 to 6761
# Data columns (total 29 columns):
# School_ID                                6762 non-null int64
# Year                                     6762 non-null int64
# Test Name                                6762 non-null object
# # Students Tested                        6762 non-null object
# Overall_ELA_Mean_Scale_Score             6761 non-null object
# % Did Not Meet                           6762 non-null object
# % Partially Met                          6762 non-null object
# % Approached                             6762 non-null object
# % Met                                    6762 non-null object
# % Exceeded                               6762 non-null object
# % Met or Exceeded                        6762 non-null object
# Reading Mean Scale Score                 6762 non-null object
# % Did Not Yet Meet or Partially Met      6762 non-null object
# % Approached.1                           6762 non-null object
# % Met or Exceeded.1                      6762 non-null object
# % Did Not Yet Meet or Partially Met.1    6762 non-null object
# % Approached.2                           6762 non-null object
# % Met or Exceeded.2                      6762 non-null object
# % Did Not Yet Meet or Partially Met.2    6762 non-null object
# % Approached.3                           6762 non-null object
# % Met or Exceeded.3                      6762 non-null object
# Writing Mean Scale Score                 6762 non-null object
# % Did Not Yet Meet or Partially Met.3    6762 non-null object
# % Approached.4                           6762 non-null object
# % Met or Exceeded.4                      6762 non-null object
# % Did Not Yet Meet or Partially Met.4    6762 non-null object
# % Approached.5                           6762 non-null object
# % Met or Exceeded.5                      6762 non-null object
# Overall_ELA_Mean_Scale_Score_numbers     5609 non-null float64
# dtypes: float64(1), int64(2), object(26)
# memory usage: 1.5+ MB

# %% [markdown]
# We are dealing with unnamed columns. Source: https://stackoverflow.com/questions/43983622/remove-unnamed-columns-in-pandas-dataframe

# %%
data=df.dropna(how='all', axis='columns')
data.head()
# Out:
#    School_ID  Year                Test Name # Students Tested  \
# 0     400009  2017  Combined ELA Grades 3-8               179
# 1     400011  2017  Combined ELA Grades 3-8               297
# 2     400017  2017  Combined ELA Grades 3-8               524
# 3     400021  2017  Combined ELA Grades 3-8               330
# 4     400023  2017  Combined ELA Grades 3-8               268
#
#   Overall_ELA_Mean_Scale_Score % Did Not Meet % Partially Met % Approached  \
# 0                                      19.00%          31.30%       22.90%
# 1                                       7.70%          12.10%       38.00%
# 2                                      35.90%          28.20%       24.00%
# 3                                      27.90%          27.00%       28.20%
# 4                                       9.30%          21.60%       32.10%
#
#     % Met % Exceeded                 ...                  % Approached.3  \
# 0  26.30%      0.60%                 ...                          22.30%
# 1  38.40%      3.70%                 ...                          24.90%
# 2  10.90%      1.00%                 ...                          18.50%
# 3  15.80%      1.20%                 ...                          24.20%
# 4  33.20%      3.70%                 ...                          29.10%
#
#   % Met or Exceeded.3 Writing Mean Scale Score  \
# 0              29.10%
# 1              41.80%
# 2              16.80%
# 3              21.80%
# 4              31.00%
#
#   % Did Not Yet Meet or Partially Met.3 % Approached.4 % Met or Exceeded.4  \
# 0                                53.10%         25.10%              21.80%
# 1                                28.60%         24.60%              46.80%
# 2                                67.90%         16.60%              15.50%
# 3                                65.50%         17.00%              17.60%
# 4                                34.00%         19.80%              46.30%
#
#   % Did Not Yet Meet or Partially Met.4 % Approached.5 % Met or Exceeded.5  \
# 0                                47.50%         27.40%              25.10%
# 1                                26.90%         25.90%              47.10%
# 2                                66.40%         18.90%              14.70%
# 3                                60.30%         18.80%              20.90%
# 4                                28.40%         25.00%              46.60%
#
#   Overall_ELA_Mean_Scale_Score_numbers
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# We select only the columns to use for the analysis

# %%
data=data.filter(["School_ID", "Year", "Test Name", "# Students Tested", "Overall_ELA_Mean_Scale_Score_numbers", "Reading Mean Scale Score", "Writing Mean Scale Score"])
data.head()
# Out:
#    School_ID  Year                Test Name # Students Tested  \
# 0     400009  2017  Combined ELA Grades 3-8               179
# 1     400011  2017  Combined ELA Grades 3-8               297
# 2     400017  2017  Combined ELA Grades 3-8               524
# 3     400021  2017  Combined ELA Grades 3-8               330
# 4     400023  2017  Combined ELA Grades 3-8               268
#
#    Overall_ELA_Mean_Scale_Score_numbers Reading Mean Scale Score  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#   Writing Mean Scale Score
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# <h6>Exploratory Data Analysis</h6>

# %% [markdown]
# <strong>1- How did the pilot school 5th graders’ ELA mean scores compare to the non-pilot 5th graders in 2017 (2016 - 2017 school year)?</strong>
#
#    <strong> 1.1- What was the average score of all the pilot schools combined?</strong>

# %%
pilot_schools_selection=data[data.School_ID.isin([609880,610534, 610066,610082,610182])]
pilot_schools_selection.head()
# Out:
#      School_ID  Year                Test Name # Students Tested  \
# 154     609880  2017  Combined ELA Grades 3-8               169
# 287     610066  2017  Combined ELA Grades 3-8               108
# 297     610082  2017  Combined ELA Grades 3-8               679
# 374     610182  2017  Combined ELA Grades 3-8               168
# 483     610534  2017  Combined ELA Grades 3-8               290
#
#      Overall_ELA_Mean_Scale_Score_numbers Reading Mean Scale Score  \
# 154                                   NaN
# 287                                   NaN
# 297                                   NaN
# 374                                   NaN
# 483                                   NaN
#
#     Writing Mean Scale Score
# 154
# 287
# 297
# 374
# 483

# %% [markdown]
# We select specific rows from a column. Source: DatabyDavid=https://stackoverflow.com/questions/17071871/select-rows-from-a-dataframe-based-on-values-in-a-column-in-pandas

# %%
pilot_grade_5th = pilot_schools_selection['Test Name'] == 'ELA/Literacy Grade 5'
pilot_schools_5th=pilot_schools_selection[pilot_grade_5th]

# %%
pilot_schools_5th
# Out:
#       School_ID  Year             Test Name # Students Tested  \
# 1540     609880  2017  ELA/Literacy Grade 5                29
# 1669     610066  2017  ELA/Literacy Grade 5                27
# 1679     610082  2017  ELA/Literacy Grade 5               102
# 1753     610182  2017  ELA/Literacy Grade 5                24
# 1854     610534  2017  ELA/Literacy Grade 5                62
# 1855     610534  2017  ELA/Literacy Grade 5                62
# 4914     609880  2016  ELA/Literacy Grade 5                30
# 4915     609880  2016  ELA/Literacy Grade 5                30
# 5045     610066  2016  ELA/Literacy Grade 5                29
# 5055     610082  2016  ELA/Literacy Grade 5               112
# 5131     610182  2016  ELA/Literacy Grade 5                28
# 5232     610534  2016  ELA/Literacy Grade 5                58
#
#       Overall_ELA_Mean_Scale_Score_numbers Reading Mean Scale Score  \
# 1540                                 792.0                       64
# 1669                                 786.0                       63
# 1679                                 774.0                       55
# 1753                                 768.0                       56
# 1854                                 795.0                       68
# 1855                                 795.0                       68
# 4914                                 791.0                       68
# 4915                                 791.0                       68
# 5045                                 772.0                       59
# 5055                                 768.0                       54
# 5131                                 764.0                       54
# 5232                                 793.0                       64
#
#      Writing Mean Scale Score
# 1540                       40
# 1669                       43
# 1679                       38
# 1753                       39
# 1854                       44
# 1855                       44
# 4914                       42
# 4915                       42
# 5045                       39
# 5055                       38
# 5131                       38
# 5232                       45

# %%
pilot_schools_5th.duplicated()
# Out:
# 1540    False
# 1669    False
# 1679    False
# 1753    False
# 1854    False
# 1855     True
# 4914    False
# 4915     True
# 5045    False
# 5055    False
# 5131    False
# 5232    False
# dtype: bool

# %%
pilot_schools_selection.duplicated().sum()
# Out:
# 2

# %% [markdown]
# We tried to drop the duplicate values from 'Overall_ELA_Mean_Scale_Score,' but it doesn't work because it takes the School ID column too. Thus, we dropped by index the two values identified, according to the above data frame.
# Source: https://chrisalbon.com/python/data_wrangling/pandas_dropping_column_and_rows/
#
# 1st Fail attempt==> pilot_schools_5th.drop_duplicates("Overall_ELA_Mean_Scale_Score", keep='first', inplace=False)
# 2nd Fail attempt==> pilot_schools_5th.drop_duplicates(subset=['Overall_ELA_Mean_Scale_Score']).shape / R= 9,7 ==> It considered three duplicated values instead of two values or "True"

# %%
#Deleting duplicate rows at index position 5 & 6
pilot_schools_5th_non_duplicates=pilot_schools_5th.drop(pilot_schools_5th.index[[5,6]])
pilot_schools_5th_non_duplicates
# Out:
#       School_ID  Year             Test Name # Students Tested  \
# 1540     609880  2017  ELA/Literacy Grade 5                29
# 1669     610066  2017  ELA/Literacy Grade 5                27
# 1679     610082  2017  ELA/Literacy Grade 5               102
# 1753     610182  2017  ELA/Literacy Grade 5                24
# 1854     610534  2017  ELA/Literacy Grade 5                62
# 4915     609880  2016  ELA/Literacy Grade 5                30
# 5045     610066  2016  ELA/Literacy Grade 5                29
# 5055     610082  2016  ELA/Literacy Grade 5               112
# 5131     610182  2016  ELA/Literacy Grade 5                28
# 5232     610534  2016  ELA/Literacy Grade 5                58
#
#       Overall_ELA_Mean_Scale_Score_numbers Reading Mean Scale Score  \
# 1540                                 792.0                       64
# 1669                                 786.0                       63
# 1679                                 774.0                       55
# 1753                                 768.0                       56
# 1854                                 795.0                       68
# 4915                                 791.0                       68
# 5045                                 772.0                       59
# 5055                                 768.0                       54
# 5131                                 764.0                       54
# 5232                                 793.0                       64
#
#      Writing Mean Scale Score
# 1540                       40
# 1669                       43
# 1679                       38
# 1753                       39
# 1854                       44
# 4915                       42
# 5045                       39
# 5055                       38
# 5131                       38
# 5232                       45

# %% [markdown]
# "The mean of means is simply the mean of all of the means of several samples. By calculating the mean of the sample means, you have a single value that can help summarize a lot of data.
# The mean of means, notated here as μx¯¯¯, is actually a pretty straightforward calculation. Simply sum the means of all your samples and divide by the number of means."
# Source:https://www.ck12.org/book/CK-12-Probability-and-Statistics-Concepts/section/9.6/

# %%
total_mean_pilot_schools_5thgrade=pilot_schools_5th_non_duplicates['Overall_ELA_Mean_Scale_Score_numbers'].mean()
print(total_mean_pilot_schools_5thgrade)
# Out:
# 780.3

# %% [markdown]
#   <strong>1.2- What was the average score of all the non-pilot schools combined?</strong>

# %%
#Source: https://stackoverflow.com/questions/17097643/search-for-does-not-contain-on-a-dataframe-in-pandas
nonpilot_schools_selection=data[data["School_ID"].apply(lambda x:x not in [609880,610534, 610066,610082,610182])] 
nonpilot_schools_selection.head()
# Out:
#    School_ID  Year                Test Name # Students Tested  \
# 0     400009  2017  Combined ELA Grades 3-8               179
# 1     400011  2017  Combined ELA Grades 3-8               297
# 2     400017  2017  Combined ELA Grades 3-8               524
# 3     400021  2017  Combined ELA Grades 3-8               330
# 4     400023  2017  Combined ELA Grades 3-8               268
#
#    Overall_ELA_Mean_Scale_Score_numbers Reading Mean Scale Score  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#   Writing Mean Scale Score
# 0
# 1
# 2
# 3
# 4

# %%
nonpilot_schools_selection.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6698 entries, 0 to 6761
# Data columns (total 7 columns):
# School_ID                               6698 non-null int64
# Year                                    6698 non-null int64
# Test Name                               6698 non-null object
# # Students Tested                       6698 non-null object
# Overall_ELA_Mean_Scale_Score_numbers    5555 non-null float64
# Reading Mean Scale Score                6698 non-null object
# Writing Mean Scale Score                6698 non-null object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 418.6+ KB

# %%
nonpilot_grade_5th= nonpilot_schools_selection['Test Name'] == 'ELA/Literacy Grade 5'
nonpilot_schools_5th=nonpilot_schools_selection[nonpilot_grade_5th]

# %%
nonpilot_schools_5th.head()
# Out:
#       School_ID  Year             Test Name # Students Tested  \
# 1408     400009  2017  ELA/Literacy Grade 5                30
# 1409     400011  2017  ELA/Literacy Grade 5                49
# 1410     400021  2017  ELA/Literacy Grade 5                55
# 1411     400023  2017  ELA/Literacy Grade 5                55
# 1412     400024  2017  ELA/Literacy Grade 5                65
#
#       Overall_ELA_Mean_Scale_Score_numbers Reading Mean Scale Score  \
# 1408                                 709.0                       36
# 1409                                 744.0                       47
# 1410                                 718.0                       38
# 1411                                 733.0                       43
# 1412                                 734.0                       44
#
#      Writing Mean Scale Score
# 1408                       18
# 1409                       33
# 1410                       24
# 1411                       30
# 1412                       30

# %%
nonpilot_schools_5th.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 905 entries, 1408 to 5238
# Data columns (total 7 columns):
# School_ID                               905 non-null int64
# Year                                    905 non-null int64
# Test Name                               905 non-null object
# # Students Tested                       905 non-null object
# Overall_ELA_Mean_Scale_Score_numbers    905 non-null float64
# Reading Mean Scale Score                905 non-null object
# Writing Mean Scale Score                905 non-null object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 56.6+ KB

# %%
nonpilot_schools_5th.duplicated().sum()
# Out:
# 0

# %% [markdown]
# After checked duplicates values of the whole dataframe, we can proceed to calculate nonpilot schools mean

# %%
type(nonpilot_schools_5th)
# Out:
# pandas.core.frame.DataFrame

# %%
total_mean_nonpilot_schools_5thgrade=nonpilot_schools_5th['Overall_ELA_Mean_Scale_Score_numbers'].mean()
print(total_mean_nonpilot_schools_5thgrade)
# Out:
# 725.2696132596685

# %% [markdown]
# <strong>2- Which pilot school exhibited the most growth in ELA mean scale scores?</strong>
#
# <strong>2.1- Which pilot school exhibited the most growth in ELA mean scale scores from the 2016 test through the 2017 test</strong>

# %%
grow_ELAscore_pilot_shools_2016_2017=pilot_schools_5th_non_duplicates.groupby('School_ID').Overall_ELA_Mean_Scale_Score_numbers.mean().reset_index()
print(grow_ELAscore_pilot_shools_2016_2017)
# Out:
#    School_ID  Overall_ELA_Mean_Scale_Score_numbers
# 0     609880                                 791.5
# 1     610066                                 779.0
# 2     610082                                 771.0
# 3     610182                                 766.0
# 4     610534                                 794.0

# %%
School_ID_grow_ELAscore_pilot_shools_2016_2017=grow_ELAscore_pilot_shools_2016_2017.School_ID
School_ID_grow_ELAscore_pilot_shools_2016_2017
# Out:
# 0    609880
# 1    610066
# 2    610082
# 3    610182
# 4    610534
# Name: School_ID, dtype: int64

# %%
Grow_ELA_mean_score_pilot_shools_2016_2017=grow_ELAscore_pilot_shools_2016_2017.Overall_ELA_Mean_Scale_Score_numbers
Grow_ELA_mean_score_pilot_shools_2016_2017
# Out:
# 0    791.5
# 1    779.0
# 2    771.0
# 3    766.0
# 4    794.0
# Name: Overall_ELA_Mean_Scale_Score_numbers, dtype: float64

# %%
plt.figure(figsize=(6,4))
ax=plt.subplot()
plt.bar(range(len(Grow_ELA_mean_score_pilot_shools_2016_2017)),Grow_ELA_mean_score_pilot_shools_2016_2017)
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels(School_ID_grow_ELAscore_pilot_shools_2016_2017)
plt.xticks(rotation=45)
plt.subplots_adjust(bottom=0.10)
plt.title("Pilot Schools growth in ELA mean scale scores 2016-2017")
plt.xlabel('School ID') 
plt.ylabel('Overall_ELA_Mean_Scale_Score')
plt.savefig('Pilot Schools growth in ELA mean scale scores.png')
plt.show()

# %% [markdown]
# <strong>2.1- What is the percentage difference in this school’s 5th grade growth from 2016 through 2017 compared to the other pilot schools’ 5th grade average growth during the same time period?</strong>

# %%
#Source; https://stackoverflow.com/questions/34682828/extracting-specific-selected-columns-to-new-dataframe-as-a-copy
new = pilot_schools_5th_non_duplicates[['School_ID','Year','Overall_ELA_Mean_Scale_Score_numbers']].copy()
new
# Out:
#       School_ID  Year  Overall_ELA_Mean_Scale_Score_numbers
# 1540     609880  2017                                 792.0
# 1669     610066  2017                                 786.0
# 1679     610082  2017                                 774.0
# 1753     610182  2017                                 768.0
# 1854     610534  2017                                 795.0
# 4915     609880  2016                                 791.0
# 5045     610066  2016                                 772.0
# 5055     610082  2016                                 768.0
# 5131     610182  2016                                 764.0
# 5232     610534  2016                                 793.0

# %% [markdown]
# We want to know the performance of each pilot school by year (2016 and 2017). We are using Group by and Split. Source: https://www.youtube.com/watch?v=Wb2Tp35dZ-I

# %%
Year_pilot_schools=pilot_schools_5th_non_duplicates.groupby('Year')
Year_pilot_schools

# %%
for Year, Overall_ELA_Mean_Scale_Score_numbers in Year_pilot_schools:
    print(Year)
    print(Overall_ELA_Mean_Scale_Score_numbers)
# Out:
# 2016
#       School_ID  Year             Test Name # Students Tested  \
# 4915     609880  2016  ELA/Literacy Grade 5                30
# 5045     610066  2016  ELA/Literacy Grade 5                29
# 5055     610082  2016  ELA/Literacy Grade 5               112
# 5131     610182  2016  ELA/Literacy Grade 5                28
# 5232     610534  2016  ELA/Literacy Grade 5                58
#
#       Overall_ELA_Mean_Scale_Score_numbers Reading Mean Scale Score  \
# 4915                                 791.0                       68
# 5045                                 772.0                       59
# 5055                                 768.0                       54
# 5131                                 764.0                       54
# 5232                                 793.0                       64
#
#      Writing Mean Scale Score
# 4915                       42
# 5045                       39
# 5055                       38
# 5131                       38
# 5232                       45
# 2017
#       School_ID  Year             Test Name # Students Tested  \
# 1540     609880  2017  ELA/Literacy Grade 5                29
# 1669     610066  2017  ELA/Literacy Grade 5                27
# 1679     610082  2017  ELA/Literacy Grade 5               102
# 1753     610182  2017  ELA/Literacy Grade 5                24
# 1854     610534  2017  ELA/Literacy Grade 5                62
#
#       Overall_ELA_Mean_Scale_Score_numbers Reading Mean Scale Score  \
# 1540                                 792.0                       64
# 1669                                 786.0                       63
# 1679                                 774.0                       55
# 1753                                 768.0                       56
# 1854                                 795.0                       68
#
#      Writing Mean Scale Score
# 1540                       40
# 1669                       43
# 1679                       38
# 1753                       39
# 1854                       44

# %%
First_values=Year_pilot_schools.get_group(2016)
First_values
# Out:
#       School_ID  Year             Test Name # Students Tested  \
# 4915     609880  2016  ELA/Literacy Grade 5                30
# 5045     610066  2016  ELA/Literacy Grade 5                29
# 5055     610082  2016  ELA/Literacy Grade 5               112
# 5131     610182  2016  ELA/Literacy Grade 5                28
# 5232     610534  2016  ELA/Literacy Grade 5                58
#
#       Overall_ELA_Mean_Scale_Score_numbers Reading Mean Scale Score  \
# 4915                                 791.0                       68
# 5045                                 772.0                       59
# 5055                                 768.0                       54
# 5131                                 764.0                       54
# 5232                                 793.0                       64
#
#      Writing Mean Scale Score
# 4915                       42
# 5045                       39
# 5055                       38
# 5131                       38
# 5232                       45

# %%
Second_values=Year_pilot_schools.get_group(2017)
Second_values
# Out:
#       School_ID  Year             Test Name # Students Tested  \
# 1540     609880  2017  ELA/Literacy Grade 5                29
# 1669     610066  2017  ELA/Literacy Grade 5                27
# 1679     610082  2017  ELA/Literacy Grade 5               102
# 1753     610182  2017  ELA/Literacy Grade 5                24
# 1854     610534  2017  ELA/Literacy Grade 5                62
#
#       Overall_ELA_Mean_Scale_Score_numbers Reading Mean Scale Score  \
# 1540                                 792.0                       64
# 1669                                 786.0                       63
# 1679                                 774.0                       55
# 1753                                 768.0                       56
# 1854                                 795.0                       68
#
#      Writing Mean Scale Score
# 1540                       40
# 1669                       43
# 1679                       38
# 1753                       39
# 1854                       44

# %% [markdown]
# Now the schools are splits by year we can subtract each column "Overall_ELA_Mean_Scale_Score" by year. After multiple attempts, we prefer this solution by collections and dictionaries. Source: https://pythontic.com/containers/counter/subtract, https://docs.python.org/3/library/collections.html

# %% [markdown]
# The difference between each pilot school:

# %%
import collections

# %%
# create two boxes

year2016 = collections.Counter({"609880":791,"610066":772,"610082":768,"610182":764, "610534":793})

year2017 = collections.Counter({"609880":792,"610066":786,"610082":774,"610182":768, "610534":795}) 

# subtract year2017 from year2016

ret = year2016.subtract(year2017)

#print year2016 contents

print(year2016)
# Out:
# Counter({'609880': -1, '610534': -2, '610182': -4, '610082': -6, '610066': -14})

# %% [markdown]
# By hand, we create a variable with the previous dictionary values but omitting the negative sings

# %%
dict_sub_years=({'609880':[1], '610534': [2], '610182': [4], '610082': [6], '610066': [14]})

# %% [markdown]
# Converting dictionary to dataframe

# %%
frame_sub_years=pd.DataFrame.from_dict(dict_sub_years)
frame_sub_years
# Out:
#    609880  610066  610082  610182  610534
# 0       1      14       6       4       2

# %% [markdown]
# Average of each pilot school:
#
#  <p>a)Sum</p>

# %%
year_2016 = {"609880":791,"610066":772,"610082":768,"610182":764, "610534":793}

year_2017 = {"609880":792,"610066":786,"610082":774,"610182":768, "610534":795}

# %%
#Source:https://stackoverflow.com/questions/10461531/merge-and-sum-of-two-dictionaries
print({ k: year_2016.get(k, 0) + year_2017.get(k, 0) for k in set(year_2016) })
# Out:
# {'610182': 1532, '610082': 1542, '610534': 1588, '610066': 1558, '609880': 1583}

# %% [markdown]
# By hand, we create a variable with the previous dictionary values

# %%
dict_sum_years={'610534':[1588], '609880': [1583], '610182': [1532], '610066': [1558], '610082': [1542]}

# %% [markdown]
# Converting dictionary to dataframe

# %%
frame_sum_years=pd.DataFrame.from_dict(dict_sum_years)
frame_sum_years
# Out:
#    609880  610066  610082  610182  610534
# 0    1583    1558    1542    1532    1588

# %% [markdown]
# <p>b)Average</p>

# %%
frame_avg_sum_years=frame_sum_years.iloc[:, :]/2
frame_avg_sum_years
# Out:
#    609880  610066  610082  610182  610534
# 0   791.5   779.0   771.0   766.0   794.0

# %% [markdown]
# To get the percentage of the difference, we must divide frame_sub_years/frame_avg_sum_years*100

# %%
percentage_difference_pilot_schools=(frame_sub_years/frame_avg_sum_years)*100
percentage_difference_pilot_schools
# Out:
#      609880    610066   610082    610182    610534
# 0  0.126342  1.797176  0.77821  0.522193  0.251889

# %% [markdown]
# <h2> II Dataset : for 3rd and 4th questions <h2>

# %% [markdown]
# <h6>Data Wrangling </h6>

# %%
df2 = pd.read_csv('C:/Users/Franchi/Desktop/data exercise2.csv')
df2.head()
# Out:
#   School_Year  School_ID  Total  Bilingual_N Bilingual_%  SpED_N  SpED_%  \
# 0        2017     610212    277         56.0      20.22%    42.0  15.16%
# 1        2017     610209    921        522.0      56.68%    99.0  10.75%
# 2        2017     609836    849        159.0      18.73%   104.0  12.25%
# 3        2017     609729   1812        320.0      17.66%   336.0  18.54%
# 4        2017     610083    173         66.0      38.15%   114.0  65.90%
#
#    Free_Reduced_Lunch_N  Free_Reduced_Lunch_%
# 0                   264                0.9531
# 1                   842                0.9142
# 2                   404                0.4759
# 3                  1649                0.9100
# 4                    95                0.5491

# %% [markdown]
# <h6>Data Cleaning</h6>

# %% [markdown]
# <ol>Changes in the cvs file:
# <li>The first row was deleted and modified because of when imported it the title of columns were 'unnamed.'</li>
# <li>School_Year and School_ID column names are changed because we added underscore sing.</li>
# <li>The datatype of Free_ReducedLunch% changed to general and without the percentage sign.</li>
# <li>The datatype of Total and Free_Reduced_Lunch_N, changed from General type to Number type and decrease decimal, avoiding the comma sign (Ex. 1,812)</li>

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2018 entries, 0 to 2017
# Data columns (total 9 columns):
# School_Year             2018 non-null object
# School_ID               2018 non-null int64
# Total                   2018 non-null int64
# Bilingual_N             1824 non-null float64
# Bilingual_%             1824 non-null object
# SpED_N                  2016 non-null float64
# SpED_%                  2016 non-null object
# Free_Reduced_Lunch_N    2018 non-null int64
# Free_Reduced_Lunch_%    2018 non-null float64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 142.0+ KB

# %% [markdown]
# Due to our column object is Free/Reduced lunch we don't care about the null values from Bilingual column.

# %% [markdown]
# Changing data types by pandas.to_numeric method. Source:https://www.geeksforgeeks.org/python-pandas-to_numeric-method/

# %%
df2.dtypes
# Out:
# School_Year              object
# School_ID                 int64
# Total                     int64
# Bilingual_N             float64
# Bilingual_%              object
# SpED_N                  float64
# SpED_%                   object
# Free_Reduced_Lunch_N      int64
# Free_Reduced_Lunch_%    float64
# dtype: object

# %% [markdown]
# The "School_Year" and "School_ID" name columns changed from the original csv

# %% [markdown]
# We select specific columns to use for the analysis

# %%
data2=df2.filter(["School_Year","School_ID", "Total", "Free_Reduced_Lunch_N", "Free_Reduced_Lunch_%"])
data2.head()
# Out:
#   School_Year  School_ID  Total  Free_Reduced_Lunch_N  Free_Reduced_Lunch_%
# 0        2017     610212    277                   264                0.9531
# 1        2017     610209    921                   842                0.9142
# 2        2017     609836    849                   404                0.4759
# 3        2017     609729   1812                  1649                0.9100
# 4        2017     610083    173                    95                0.5491

# %% [markdown]
# <h6>Exploratory Data Analysis</h6>

# %% [markdown]
# <strong>3- What was the average percentage of students who received free/reduced lunch in the 5 pilot schools in 2017?</strong>

# %%
free_lunch_pilot_schools_selection=data2[data2.School_ID.isin([609880,610534, 610066,610082,610182])]
free_lunch_pilot_schools_selection
# Out:
#      School_Year  School_ID  Total  Free_Reduced_Lunch_N  Free_Reduced_Lunch_%
# 13          2017     610182    360                   199                0.5528
# 68          2017     609880    292                    40                0.1370
# 380         2017     610066    196                    64                0.3265
# 501         2017     610082   1107                   190                0.1716
# 507         2017     610534    488                    46                0.0943
# 902         2016     610182    355                   192                0.5408
# 941         2016     610066    192                    83                0.4323
# 1092        2016     610082   1055                   214                0.2028
# 1216        2016     610534    478                    82                0.1715
# 1225        2016     609880    282                    37                0.1312
# 1579        2015     610182    358                   226                0.6313
# 1619        2015     610066    182                    80                0.4396
# 1769        2015     610082   1059                   268                0.2531
# 1893        2015     610534    418                    74                0.1770
# 1902        2015     609880    289                    41                0.1419

# %%
free_lunch_pilot_grade_2017 = free_lunch_pilot_schools_selection['School_Year'] == '2017'
free_lunch_pilot_schools_2017=free_lunch_pilot_schools_selection[free_lunch_pilot_grade_2017]

# %%
free_lunch_pilot_schools_2017
# Out:
#     School_Year  School_ID  Total  Free_Reduced_Lunch_N  Free_Reduced_Lunch_%
# 13         2017     610182    360                   199                0.5528
# 68         2017     609880    292                    40                0.1370
# 380        2017     610066    196                    64                0.3265
# 501        2017     610082   1107                   190                0.1716
# 507        2017     610534    488                    46                0.0943

# %%
sum_total_pilot_schools_2017=free_lunch_pilot_schools_2017['Total'].sum()
print(sum_total_pilot_schools_2017)
# Out:
# 2443

# %%
sum_free_lunch_pilot_schools_2017=free_lunch_pilot_schools_2017['Free_Reduced_Lunch_N'].sum()
print(sum_free_lunch_pilot_schools_2017)
# Out:
# 539

# %%
avg_pecentage_select_pilot_schools=sum_free_lunch_pilot_schools_2017*100/sum_total_pilot_schools_2017
avg_pecentage_select_pilot_schools
# Out:
# 22.063037249283667

# %% [markdown]
# That's mean 22% average percentage of students who received free/reduced lunch in the five pilot schools in 2017

# %% [markdown]
# <strong> 4- What was the average ELA mean test score of the non-pilot schools that have an equal or greater percentage of students who qualify for free/reduced lunch as the pilot schools? Only look at the 5th grade class in the 2017 school year.</strong>

# %% [markdown]
# Verifying the primary key datatype

# %%
print (df['School_ID'].dtypes)
print (df2['School_ID'].dtypes)
# Out:
# int64
# int64

# %% [markdown]
# Merging the two datasets into one

# %%
merged = pd.merge(df, df2, how="left", on="School_ID")
merged
# Out:
#        School_ID  Year                Test Name # Students Tested  \
# 0         400009  2017  Combined ELA Grades 3-8               179
# 1         400009  2017  Combined ELA Grades 3-8               179
# 2         400009  2017  Combined ELA Grades 3-8               179
# 3         400011  2017  Combined ELA Grades 3-8               297
# 4         400011  2017  Combined ELA Grades 3-8               297
# 5         400011  2017  Combined ELA Grades 3-8               297
# 6         400017  2017  Combined ELA Grades 3-8               524
# 7         400017  2017  Combined ELA Grades 3-8               524
# 8         400017  2017  Combined ELA Grades 3-8               524
# 9         400021  2017  Combined ELA Grades 3-8               330
# 10        400021  2017  Combined ELA Grades 3-8               330
# 11        400021  2017  Combined ELA Grades 3-8               330
# 12        400023  2017  Combined ELA Grades 3-8               268
# 13        400023  2017  Combined ELA Grades 3-8               268
# 14        400023  2017  Combined ELA Grades 3-8               268
# 15        400024  2017  Combined ELA Grades 3-8               456
# 16        400024  2017  Combined ELA Grades 3-8               456
# 17        400024  2017  Combined ELA Grades 3-8               456
# 18        400025  2017  Combined ELA Grades 3-8               443
# 19        400025  2017  Combined ELA Grades 3-8               443
# 20        400025  2017  Combined ELA Grades 3-8               443
# 21        400027  2017  Combined ELA Grades 3-8               360
# 22        400027  2017  Combined ELA Grades 3-8               360
# 23        400027  2017  Combined ELA Grades 3-8               360
# 24        400028  2017  Combined ELA Grades 3-8               249
# 25        400028  2017  Combined ELA Grades 3-8               249
# 26        400028  2017  Combined ELA Grades 3-8               249
# 27        400029  2017  Combined ELA Grades 3-8               277
# 28        400029  2017  Combined ELA Grades 3-8               277
# 29        400029  2017  Combined ELA Grades 3-8               277
# ...          ...   ...                      ...               ...
# 20171     609728  2016  ELA/Literacy I Grade 11                10
# 20172     609728  2016  ELA/Literacy I Grade 11                10
# 20173     609728  2016  ELA/Literacy I Grade 11                10
# 20174     609729  2016  ELA/Literacy I Grade 11                11
# 20175     609729  2016  ELA/Literacy I Grade 11                11
# 20176     609729  2016  ELA/Literacy I Grade 11                11
# 20177     609730  2016  ELA/Literacy I Grade 11                11
# 20178     609730  2016  ELA/Literacy I Grade 11                11
# 20179     609730  2016  ELA/Literacy I Grade 11                11
# 20180     400143  2016  ELA/Literacy I Grade 12                13
# 20181     400143  2016  ELA/Literacy I Grade 12                13
# 20182     400143  2016  ELA/Literacy I Grade 12                13
# 20183     400145  2016  ELA/Literacy I Grade 12                21
# 20184     400145  2016  ELA/Literacy I Grade 12                21
# 20185     400145  2016  ELA/Literacy I Grade 12                21
# 20186     609715  2016  ELA/Literacy I Grade 12                13
# 20187     609715  2016  ELA/Literacy I Grade 12                13
# 20188     609715  2016  ELA/Literacy I Grade 12                13
# 20189     609724  2016  ELA/Literacy I Grade 12                14
# 20190     609724  2016  ELA/Literacy I Grade 12                14
# 20191     609724  2016  ELA/Literacy I Grade 12                14
# 20192     609728  2016  ELA/Literacy I Grade 12                12
# 20193     609728  2016  ELA/Literacy I Grade 12                12
# 20194     609728  2016  ELA/Literacy I Grade 12                12
# 20195     609729  2016  ELA/Literacy I Grade 12                20
# 20196     609729  2016  ELA/Literacy I Grade 12                20
# 20197     609729  2016  ELA/Literacy I Grade 12                20
# 20198     609732  2016  ELA/Literacy I Grade 12                10
# 20199     609732  2016  ELA/Literacy I Grade 12                10
# 20200     609732  2016  ELA/Literacy I Grade 12                10
#
#       Overall_ELA_Mean_Scale_Score % Did Not Meet % Partially Met  \
# 0                                          19.00%          31.30%
# 1                                          19.00%          31.30%
# 2                                          19.00%          31.30%
# 3                                           7.70%          12.10%
# 4                                           7.70%          12.10%
# 5                                           7.70%          12.10%
# 6                                          35.90%          28.20%
# 7                                          35.90%          28.20%
# 8                                          35.90%          28.20%
# 9                                          27.90%          27.00%
# 10                                         27.90%          27.00%
# 11                                         27.90%          27.00%
# 12                                          9.30%          21.60%
# 13                                          9.30%          21.60%
# 14                                          9.30%          21.60%
# 15                                         14.50%          21.10%
# 16                                         14.50%          21.10%
# 17                                         14.50%          21.10%
# 18                             NaN         21.00%          28.90%
# 19                             NaN         21.00%          28.90%
# 20                             NaN         21.00%          28.90%
# 21                                         11.70%          18.90%
# 22                                         11.70%          18.90%
# 23                                         11.70%          18.90%
# 24                                         23.70%          27.30%
# 25                                         23.70%          27.30%
# 26                                         23.70%          27.30%
# 27                                         16.60%          22.70%
# 28                                         16.60%          22.70%
# 29                                         16.60%          22.70%
# ...                            ...            ...             ...
# 20171                          699         40.00%          50.00%
# 20172                          699         40.00%          50.00%
# 20173                          699         40.00%          50.00%
# 20174                          687         63.60%          36.40%
# 20175                          687         63.60%          36.40%
# 20176                          687         63.60%          36.40%
# 20177                          719         27.30%          36.40%
# 20178                          719         27.30%          36.40%
# 20179                          719         27.30%          36.40%
# 20180                          698         46.20%          46.20%
# 20181                          698         46.20%          46.20%
# 20182                          698         46.20%          46.20%
# 20183                          706         42.90%          28.60%
# 20184                          706         42.90%          28.60%
# 20185                          706         42.90%          28.60%
# 20186                          698         61.50%          23.10%
# 20187                          698         61.50%          23.10%
# 20188                          698         61.50%          23.10%
# 20189                          701         64.30%          21.40%
# 20190                          701         64.30%          21.40%
# 20191                          701         64.30%          21.40%
# 20192                          690         75.00%          25.00%
# 20193                          690         75.00%          25.00%
# 20194                          690         75.00%          25.00%
# 20195                          701         55.00%          30.00%
# 20196                          701         55.00%          30.00%
# 20197                          701         55.00%          30.00%
# 20198                          689         70.00%          20.00%
# 20199                          689         70.00%          20.00%
# 20200                          689         70.00%          20.00%
#
#       % Approached   % Met % Exceeded         ...           \
# 0           22.90%  26.30%      0.60%         ...
# 1           22.90%  26.30%      0.60%         ...
# 2           22.90%  26.30%      0.60%         ...
# 3           38.00%  38.40%      3.70%         ...
# 4           38.00%  38.40%      3.70%         ...
# 5           38.00%  38.40%      3.70%         ...
# 6           24.00%  10.90%      1.00%         ...
# 7           24.00%  10.90%      1.00%         ...
# 8           24.00%  10.90%      1.00%         ...
# 9           28.20%  15.80%      1.20%         ...
# 10          28.20%  15.80%      1.20%         ...
# 11          28.20%  15.80%      1.20%         ...
# 12          32.10%  33.20%      3.70%         ...
# 13          32.10%  33.20%      3.70%         ...
# 14          32.10%  33.20%      3.70%         ...
# 15          34.00%  29.60%      0.90%         ...
# 16          34.00%  29.60%      0.90%         ...
# 17          34.00%  29.60%      0.90%         ...
# 18          28.90%  19.60%      1.60%         ...
# 19          28.90%  19.60%      1.60%         ...
# 20          28.90%  19.60%      1.60%         ...
# 21          30.00%  35.00%      4.40%         ...
# 22          30.00%  35.00%      4.40%         ...
# 23          30.00%  35.00%      4.40%         ...
# 24          30.50%  16.90%      1.60%         ...
# 25          30.50%  16.90%      1.60%         ...
# 26          30.50%  16.90%      1.60%         ...
# 27          31.80%  27.10%      1.80%         ...
# 28          31.80%  27.10%      1.80%         ...
# 29          31.80%  27.10%      1.80%         ...
# ...            ...     ...        ...         ...
# 20171       10.00%   0.00%      0.00%         ...
# 20172       10.00%   0.00%      0.00%         ...
# 20173       10.00%   0.00%      0.00%         ...
# 20174        0.00%   0.00%      0.00%         ...
# 20175        0.00%   0.00%      0.00%         ...
# 20176        0.00%   0.00%      0.00%         ...
# 20177        9.10%  27.30%      0.00%         ...
# 20178        9.10%  27.30%      0.00%         ...
# 20179        9.10%  27.30%      0.00%         ...
# 20180        7.70%   0.00%      0.00%         ...
# 20181        7.70%   0.00%      0.00%         ...
# 20182        7.70%   0.00%      0.00%         ...
# 20183       28.60%   0.00%      0.00%         ...
# 20184       28.60%   0.00%      0.00%         ...
# 20185       28.60%   0.00%      0.00%         ...
# 20186       15.40%   0.00%      0.00%         ...
# 20187       15.40%   0.00%      0.00%         ...
# 20188       15.40%   0.00%      0.00%         ...
# 20189        7.10%   7.10%      0.00%         ...
# 20190        7.10%   7.10%      0.00%         ...
# 20191        7.10%   7.10%      0.00%         ...
# 20192        0.00%   0.00%      0.00%         ...
# 20193        0.00%   0.00%      0.00%         ...
# 20194        0.00%   0.00%      0.00%         ...
# 20195       15.00%   0.00%      0.00%         ...
# 20196       15.00%   0.00%      0.00%         ...
# 20197       15.00%   0.00%      0.00%         ...
# 20198       10.00%   0.00%      0.00%         ...
# 20199       10.00%   0.00%      0.00%         ...
# 20200       10.00%   0.00%      0.00%         ...
#
#       % Met or Exceeded.5 Overall_ELA_Mean_Scale_Score_numbers School_Year  \
# 0                  25.10%                                  NaN        2017
# 1                  25.10%                                  NaN     Charter
# 2                  25.10%                                  NaN        2015
# 3                  47.10%                                  NaN        2017
# 4                  47.10%                                  NaN        2016
# 5                  47.10%                                  NaN        2015
# 6                  14.70%                                  NaN        2017
# 7                  14.70%                                  NaN        2016
# 8                  14.70%                                  NaN        2015
# 9                  20.90%                                  NaN        2017
# 10                 20.90%                                  NaN        2016
# 11                 20.90%                                  NaN        2015
# 12                 46.60%                                  NaN        2017
# 13                 46.60%                                  NaN        2016
# 14                 46.60%                                  NaN        2015
# 15                 39.70%                                  NaN        2017
# 16                 39.70%                                  NaN        2016
# 17                 39.70%                                  NaN        2015
# 18                 29.60%                                  NaN        2017
# 19                 29.60%                                  NaN        2016
# 20                 29.60%                                  NaN        2015
# 21                 45.30%                                  NaN        2017
# 22                 45.30%                                  NaN        2016
# 23                 45.30%                                  NaN        2015
# 24                 27.70%                                  NaN        2017
# 25                 27.70%                                  NaN        2016
# 26                 27.70%                                  NaN        2015
# 27                 33.20%                                  NaN        2017
# 28                 33.20%                                  NaN        2016
# 29                 33.20%                                  NaN        2015
# ...                   ...                                  ...         ...
# 20171               0.00%                                699.0        2017
# 20172               0.00%                                699.0        2016
# 20173               0.00%                                699.0        2015
# 20174               0.00%                                687.0        2017
# 20175               0.00%                                687.0        2016
# 20176               0.00%                                687.0        2015
# 20177              27.30%                                719.0        2017
# 20178              27.30%                                719.0        2016
# 20179              27.30%                                719.0        2015
# 20180               0.00%                                698.0        2017
# 20181               0.00%                                698.0        2016
# 20182               0.00%                                698.0        2015
# 20183               4.80%                                706.0        2017
# 20184               4.80%                                706.0        2016
# 20185               4.80%                                706.0        2015
# 20186               0.00%                                698.0        2017
# 20187               0.00%                                698.0        2016
# 20188               0.00%                                698.0        2015
# 20189               7.10%                                701.0        2017
# 20190               7.10%                                701.0        2016
# 20191               7.10%                                701.0        2015
# 20192               0.00%                                690.0        2017
# 20193               0.00%                                690.0        2016
# 20194               0.00%                                690.0        2015
# 20195               0.00%                                701.0        2017
# 20196               0.00%                                701.0        2016
# 20197               0.00%                                701.0        2015
# 20198               0.00%                                689.0        2017
# 20199               0.00%                                689.0        2016
# 20200               0.00%                                689.0        2015
#
#         Total Bilingual_N Bilingual_% SpED_N  SpED_% Free_Reduced_Lunch_N  \
# 0       461.0       138.0      29.93%   48.0  10.41%                320.0
# 1       450.0       124.0      27.56%   52.0  11.56%                343.0
# 2       391.0       108.0      27.62%   47.0  12.02%                306.0
# 3       550.0         NaN         NaN   48.0   8.73%                460.0
# 4       569.0         NaN         NaN   43.0   7.56%                489.0
# 5       581.0         0.0       0.00%   39.0   6.71%                545.0
# 6       537.0       113.0      21.04%   67.0  12.48%                525.0
# 7       532.0        99.0      18.61%   62.0  11.65%                512.0
# 8       578.0       114.0      19.72%   65.0  11.25%                568.0
# 9       522.0         NaN         NaN   68.0  13.03%                469.0
# 10      521.0         NaN         NaN   69.0  13.24%                471.0
# 11      516.0         0.0       0.00%   60.0  11.63%                500.0
# 12      501.0         6.0       1.20%   48.0   9.58%                416.0
# 13      421.0         NaN         NaN   44.0  10.45%                368.0
# 14      402.0         1.0       0.25%   40.0   9.95%                382.0
# 15      749.0        55.0       7.34%   74.0   9.88%                702.0
# 16      719.0        39.0       5.42%   75.0  10.43%                641.0
# 17      634.0        23.0       3.63%   66.0  10.41%                608.0
# 18      704.0       115.0      16.34%   91.0  12.93%                501.0
# 19      678.0       106.0      15.63%   89.0  13.13%                530.0
# 20      675.0       113.0      16.74%   92.0  13.63%                563.0
# 21      556.0       109.0      19.60%   60.0  10.79%                290.0
# 22      536.0        74.0      13.81%   55.0  10.26%                314.0
# 23      536.0        69.0      12.87%   47.0   8.77%                335.0
# 24      420.0       119.0      28.33%   42.0  10.00%                377.0
# 25      410.0       127.0      30.98%   53.0  12.93%                374.0
# 26      405.0       115.0      28.40%   50.0  12.35%                399.0
# 27      482.0         NaN         NaN   47.0   9.75%                436.0
# 28      453.0         NaN         NaN   48.0  10.60%                406.0
# 29      432.0         0.0       0.00%   39.0   9.03%                423.0
# ...       ...         ...         ...    ...     ...                  ...
# 20171  1198.0       312.0      26.04%  244.0  20.37%               1094.0
# 20172  1182.0       304.0      25.72%  232.0  19.63%               1094.0
# 20173  1357.0       293.0      21.59%  229.0  16.88%               1311.0
# 20174  1812.0       320.0      17.66%  336.0  18.54%               1649.0
# 20175  2002.0       347.0      17.33%  382.0  19.08%               1837.0
# 20176  2302.0       398.0      17.29%  408.0  17.72%               2156.0
# 20177  1415.0       232.0      16.40%  190.0  13.43%               1160.0
# 20178  1365.0       194.0      14.21%  188.0  13.77%               1130.0
# 20179  1281.0       187.0      14.60%  147.0  11.48%               1120.0
# 20180   161.0         3.0       1.86%   27.0  16.77%                150.0
# 20181   175.0         2.0       1.14%   35.0  20.00%                149.0
# 20182   160.0        10.0       6.25%   27.0  16.88%                154.0
# 20183   260.0         2.0       0.77%   60.0  23.08%                250.0
# 20184   260.0         NaN         NaN   56.0  21.54%                251.0
# 20185   250.0         0.0       0.00%   51.0  20.40%                242.0
# 20186  2075.0       486.0      23.42%  347.0  16.72%               1951.0
# 20187  2248.0       474.0      21.09%  315.0  14.01%               2125.0
# 20188  2290.0       471.0      20.57%  320.0  13.97%               2205.0
# 20189  1502.0       398.0      26.50%  172.0  11.45%               1270.0
# 20190  1576.0       369.0      23.41%  169.0  10.72%               1384.0
# 20191  1579.0       333.0      21.09%  170.0  10.77%               1437.0
# 20192  1198.0       312.0      26.04%  244.0  20.37%               1094.0
# 20193  1182.0       304.0      25.72%  232.0  19.63%               1094.0
# 20194  1357.0       293.0      21.59%  229.0  16.88%               1311.0
# 20195  1812.0       320.0      17.66%  336.0  18.54%               1649.0
# 20196  2002.0       347.0      17.33%  382.0  19.08%               1837.0
# 20197  2302.0       398.0      17.29%  408.0  17.72%               2156.0
# 20198  1374.0       232.0      16.89%  256.0  18.63%               1246.0
# 20199  1545.0       230.0      14.89%  272.0  17.61%               1395.0
# 20200  1709.0       244.0      14.28%  265.0  15.51%               1599.0
#
#       Free_Reduced_Lunch_%
# 0                   0.6941
# 1                   0.7622
# 2                   0.7826
# 3                   0.8364
# 4                   0.8594
# 5                   0.9380
# 6                   0.9777
# 7                   0.9624
# 8                   0.9827
# 9                   0.8985
# 10                  0.9040
# 11                  0.9690
# 12                  0.8303
# 13                  0.8741
# 14                  0.9502
# 15                  0.9372
# 16                  0.8915
# 17                  0.9590
# 18                  0.7116
# 19                  0.7817
# 20                  0.8341
# 21                  0.5216
# 22                  0.5858
# 23                  0.6250
# 24                  0.8976
# 25                  0.9122
# 26                  0.9852
# 27                  0.9046
# 28                  0.8962
# 29                  0.9792
# ...                    ...
# 20171               0.9132
# 20172               0.9255
# 20173               0.9661
# 20174               0.9100
# 20175               0.9176
# 20176               0.9366
# 20177               0.8198
# 20178               0.8278
# 20179               0.8743
# 20180               0.9317
# 20181               0.8514
# 20182               0.9625
# 20183               0.9615
# 20184               0.9654
# 20185               0.9680
# 20186               0.9402
# 20187               0.9453
# 20188               0.9629
# 20189               0.8455
# 20190               0.8782
# 20191               0.9101
# 20192               0.9132
# 20193               0.9255
# 20194               0.9661
# 20195               0.9100
# 20196               0.9176
# 20197               0.9366
# 20198               0.9068
# 20199               0.9029
# 20200               0.9356
#
# [20201 rows x 37 columns]

# %%
merged.dtypes
# Out:
# School_ID                                  int64
# Year                                       int64
# Test Name                                 object
# # Students Tested                         object
# Overall_ELA_Mean_Scale_Score              object
# % Did Not Meet                            object
# % Partially Met                           object
# % Approached                              object
# % Met                                     object
# % Exceeded                                object
# % Met or Exceeded                         object
# Reading Mean Scale Score                  object
# % Did Not Yet Meet or Partially Met       object
# % Approached.1                            object
# % Met or Exceeded.1                       object
# % Did Not Yet Meet or Partially Met.1     object
# % Approached.2                            object
# % Met or Exceeded.2                       object
# % Did Not Yet Meet or Partially Met.2     object
# % Approached.3                            object
# % Met or Exceeded.3                       object
# Writing Mean Scale Score                  object
# % Did Not Yet Meet or Partially Met.3     object
# % Approached.4                            object
# % Met or Exceeded.4                       object
# % Did Not Yet Meet or Partially Met.4     object
# % Approached.5                            object
# % Met or Exceeded.5                       object
# Overall_ELA_Mean_Scale_Score_numbers     float64
# School_Year                               object
# Total                                    float64
# Bilingual_N                              float64
# Bilingual_%                               object
# SpED_N                                   float64
# SpED_%                                    object
# Free_Reduced_Lunch_N                     float64
# Free_Reduced_Lunch_%                     float64
# dtype: object

# %% [markdown]
# We select only some columns to use for the analysis.

# %%
data_combination=merged.filter(["School_ID","School_Year","Test Name","Overall_ELA_Mean_Scale_Score_numbers","Total", "Free_Reduced_Lunch_N", "Free_Reduced_Lunch_%"])
data_combination.head()
# Out:
#    School_ID School_Year                Test Name  \
# 0     400009        2017  Combined ELA Grades 3-8
# 1     400009     Charter  Combined ELA Grades 3-8
# 2     400009        2015  Combined ELA Grades 3-8
# 3     400011        2017  Combined ELA Grades 3-8
# 4     400011        2016  Combined ELA Grades 3-8
#
#    Overall_ELA_Mean_Scale_Score_numbers  Total  Free_Reduced_Lunch_N  \
# 0                                   NaN  461.0                 320.0
# 1                                   NaN  450.0                 343.0
# 2                                   NaN  391.0                 306.0
# 3                                   NaN  550.0                 460.0
# 4                                   NaN  569.0                 489.0
#
#    Free_Reduced_Lunch_%
# 0                0.6941
# 1                0.7622
# 2                0.7826
# 3                0.8364
# 4                0.8594

# %%
data_combination.dtypes
# Out:
# School_ID                                 int64
# School_Year                              object
# Test Name                                object
# Overall_ELA_Mean_Scale_Score_numbers    float64
# Total                                   float64
# Free_Reduced_Lunch_N                    float64
# Free_Reduced_Lunch_%                    float64
# dtype: object

# %% [markdown]
# To avoid NaN in Overall_ELA_Mean_Scale_Score_num column, we change to Int and fill with zeros.

# %%
data_combination['Overall_ELA_Mean_Scale_Score_numbers'] = data_combination['Overall_ELA_Mean_Scale_Score_numbers'].fillna(0).astype(int)
data_combination.head()
# Out:
#    School_ID School_Year                Test Name  \
# 0     400009        2017  Combined ELA Grades 3-8
# 1     400009     Charter  Combined ELA Grades 3-8
# 2     400009        2015  Combined ELA Grades 3-8
# 3     400011        2017  Combined ELA Grades 3-8
# 4     400011        2016  Combined ELA Grades 3-8
#
#    Overall_ELA_Mean_Scale_Score_numbers  Total  Free_Reduced_Lunch_N  \
# 0                                     0  461.0                 320.0
# 1                                     0  450.0                 343.0
# 2                                     0  391.0                 306.0
# 3                                     0  550.0                 460.0
# 4                                     0  569.0                 489.0
#
#    Free_Reduced_Lunch_%
# 0                0.6941
# 1                0.7622
# 2                0.7826
# 3                0.8364
# 4                0.8594

# %%
data_combination.dtypes
# Out:
# School_ID                                 int64
# School_Year                              object
# Test Name                                object
# Overall_ELA_Mean_Scale_Score_numbers      int32
# Total                                   float64
# Free_Reduced_Lunch_N                    float64
# Free_Reduced_Lunch_%                    float64
# dtype: object

# %% [markdown]
# Now select the criteria wanted: first- non-pilot school Id, second - ELA/Literacy Grade 5, third- Year 2017, and fourth- Free_Reduced_Lunch_% >= 0.22

# %%
nonpilot_schools_selc1=data_combination[data_combination["School_ID"].apply(lambda x:x not in [609880,610534, 610066,610082,610182])] 
nonpilot_schools_selc1.head()
# Out:
#    School_ID School_Year                Test Name  \
# 0     400009        2017  Combined ELA Grades 3-8
# 1     400009     Charter  Combined ELA Grades 3-8
# 2     400009        2015  Combined ELA Grades 3-8
# 3     400011        2017  Combined ELA Grades 3-8
# 4     400011        2016  Combined ELA Grades 3-8
#
#    Overall_ELA_Mean_Scale_Score_numbers  Total  Free_Reduced_Lunch_N  \
# 0                                     0  461.0                 320.0
# 1                                     0  450.0                 343.0
# 2                                     0  391.0                 306.0
# 3                                     0  550.0                 460.0
# 4                                     0  569.0                 489.0
#
#    Free_Reduced_Lunch_%
# 0                0.6941
# 1                0.7622
# 2                0.7826
# 3                0.8364
# 4                0.8594

# %%
fifthgrade_nonpilot_schools_selc= nonpilot_schools_selc1['Test Name'] == 'ELA/Literacy Grade 5'
nonpilot_schools_selc2=nonpilot_schools_selc1[fifthgrade_nonpilot_schools_selc]

# %%
nonpilot_schools_selc2.head()
# Out:
#       School_ID School_Year             Test Name  \
# 4213     400009        2017  ELA/Literacy Grade 5
# 4214     400009     Charter  ELA/Literacy Grade 5
# 4215     400009        2015  ELA/Literacy Grade 5
# 4216     400011        2017  ELA/Literacy Grade 5
# 4217     400011        2016  ELA/Literacy Grade 5
#
#       Overall_ELA_Mean_Scale_Score_numbers  Total  Free_Reduced_Lunch_N  \
# 4213                                   709  461.0                 320.0
# 4214                                   709  450.0                 343.0
# 4215                                   709  391.0                 306.0
# 4216                                   744  550.0                 460.0
# 4217                                   744  569.0                 489.0
#
#       Free_Reduced_Lunch_%
# 4213                0.6941
# 4214                0.7622
# 4215                0.7826
# 4216                0.8364
# 4217                0.8594

# %%
year2107_fifthgrade_nonpilot_schools_selc= nonpilot_schools_selc2['School_Year'] == '2017'
nonpilot_schools_selc3=nonpilot_schools_selc2[year2107_fifthgrade_nonpilot_schools_selc]

# %%
nonpilot_schools_selc3.head()
# Out:
#       School_ID School_Year             Test Name  \
# 4213     400009        2017  ELA/Literacy Grade 5
# 4216     400011        2017  ELA/Literacy Grade 5
# 4219     400021        2017  ELA/Literacy Grade 5
# 4222     400023        2017  ELA/Literacy Grade 5
# 4225     400024        2017  ELA/Literacy Grade 5
#
#       Overall_ELA_Mean_Scale_Score_numbers  Total  Free_Reduced_Lunch_N  \
# 4213                                   709  461.0                 320.0
# 4216                                   744  550.0                 460.0
# 4219                                   718  522.0                 469.0
# 4222                                   733  501.0                 416.0
# 4225                                   734  749.0                 702.0
#
#       Free_Reduced_Lunch_%
# 4213                0.6941
# 4216                0.8364
# 4219                0.8985
# 4222                0.8303
# 4225                0.9372

# %% [markdown]
# According to the previous question, only 22% average percentage of students received free/reduced lunch in the five pilot schools in 2017

# %%
nonpilot_schools_selc3[nonpilot_schools_selc3['Free_Reduced_Lunch_%'] >= 0.22]
# Out:
#        School_ID School_Year             Test Name  \
# 4213      400009        2017  ELA/Literacy Grade 5
# 4216      400011        2017  ELA/Literacy Grade 5
# 4219      400021        2017  ELA/Literacy Grade 5
# 4222      400023        2017  ELA/Literacy Grade 5
# 4225      400024        2017  ELA/Literacy Grade 5
# 4228      400025        2017  ELA/Literacy Grade 5
# 4231      400027        2017  ELA/Literacy Grade 5
# 4234      400028        2017  ELA/Literacy Grade 5
# 4237      400029        2017  ELA/Literacy Grade 5
# 4240      400030        2017  ELA/Literacy Grade 5
# 4243      400031        2017  ELA/Literacy Grade 5
# 4246      400033        2017  ELA/Literacy Grade 5
# 4249      400036        2017  ELA/Literacy Grade 5
# 4252      400039        2017  ELA/Literacy Grade 5
# 4255      400040        2017  ELA/Literacy Grade 5
# 4258      400043        2017  ELA/Literacy Grade 5
# 4261      400044        2017  ELA/Literacy Grade 5
# 4264      400045        2017  ELA/Literacy Grade 5
# 4267      400046        2017  ELA/Literacy Grade 5
# 4270      400047        2017  ELA/Literacy Grade 5
# 4273      400048        2017  ELA/Literacy Grade 5
# 4276      400049        2017  ELA/Literacy Grade 5
# 4279      400050        2017  ELA/Literacy Grade 5
# 4282      400060        2017  ELA/Literacy Grade 5
# 4285      400068        2017  ELA/Literacy Grade 5
# 4288      400069        2017  ELA/Literacy Grade 5
# 4291      400071        2017  ELA/Literacy Grade 5
# 4294      400075        2017  ELA/Literacy Grade 5
# 4297      400076        2017  ELA/Literacy Grade 5
# 4300      400079        2017  ELA/Literacy Grade 5
# ...          ...         ...                   ...
# 15562     610339        2017  ELA/Literacy Grade 5
# 15565     610342        2017  ELA/Literacy Grade 5
# 15568     610345        2017  ELA/Literacy Grade 5
# 15571     610347        2017  ELA/Literacy Grade 5
# 15574     610350        2017  ELA/Literacy Grade 5
# 15577     610352        2017  ELA/Literacy Grade 5
# 15580     610353        2017  ELA/Literacy Grade 5
# 15583     610354        2017  ELA/Literacy Grade 5
# 15586     610355        2017  ELA/Literacy Grade 5
# 15589     610362        2017  ELA/Literacy Grade 5
# 15592     610363        2017  ELA/Literacy Grade 5
# 15595     610364        2017  ELA/Literacy Grade 5
# 15598     610366        2017  ELA/Literacy Grade 5
# 15601     610367        2017  ELA/Literacy Grade 5
# 15604     610368        2017  ELA/Literacy Grade 5
# 15607     610369        2017  ELA/Literacy Grade 5
# 15610     610396        2017  ELA/Literacy Grade 5
# 15613     610405        2017  ELA/Literacy Grade 5
# 15616     610503        2017  ELA/Literacy Grade 5
# 15619     610515        2017  ELA/Literacy Grade 5
# 15622     610520        2017  ELA/Literacy Grade 5
# 15625     610521        2017  ELA/Literacy Grade 5
# 15631     610530        2017  ELA/Literacy Grade 5
# 15634     610533        2017  ELA/Literacy Grade 5
# 15640     610539        2017  ELA/Literacy Grade 5
# 15643     610541        2017  ELA/Literacy Grade 5
# 15646     610542        2017  ELA/Literacy Grade 5
# 15649     610544        2017  ELA/Literacy Grade 5
# 15652     610548        2017  ELA/Literacy Grade 5
# 15655     610559        2017  ELA/Literacy Grade 5
#
#        Overall_ELA_Mean_Scale_Score_numbers   Total  Free_Reduced_Lunch_N  \
# 4213                                    709   461.0                 320.0
# 4216                                    744   550.0                 460.0
# 4219                                    718   522.0                 469.0
# 4222                                    733   501.0                 416.0
# 4225                                    734   749.0                 702.0
# 4228                                    718   704.0                 501.0
# 4231                                    738   556.0                 290.0
# 4234                                    720   420.0                 377.0
# 4237                                    730   482.0                 436.0
# 4240                                    733   531.0                 473.0
# 4243                                    713   784.0                 658.0
# 4246                                    717  1361.0                1242.0
# 4249                                    738   676.0                 460.0
# 4252                                    731   421.0                 359.0
# 4255                                    707   428.0                 384.0
# 4258                                    721   365.0                 297.0
# 4261                                    725   883.0                 795.0
# 4264                                    707   213.0                 189.0
# 4267                                    740   656.0                 567.0
# 4270                                    737   439.0                 411.0
# 4273                                    724   451.0                 407.0
# 4276                                    720   470.0                 423.0
# 4279                                    731   485.0                 377.0
# 4282                                    732   482.0                 377.0
# 4285                                    714   448.0                 425.0
# 4288                                    718   445.0                 415.0
# 4291                                    737   502.0                 442.0
# 4294                                    726   546.0                 433.0
# 4297                                    743   363.0                 239.0
# 4300                                    742   624.0                 559.0
# ...                                     ...     ...                   ...
# 15562                                   707   440.0                 407.0
# 15565                                   722   602.0                 518.0
# 15568                                   703   342.0                 315.0
# 15571                                   711   434.0                 419.0
# 15574                                   739   444.0                 365.0
# 15577                                   737   712.0                 568.0
# 15580                                   721   807.0                 687.0
# 15583                                   714   327.0                 268.0
# 15586                                   715   456.0                 393.0
# 15589                                   722   316.0                 280.0
# 15592                                   748  1564.0                 899.0
# 15595                                   706   256.0                 252.0
# 15598                                   717   289.0                 217.0
# 15601                                   708   614.0                 592.0
# 15604                                   715   486.0                 399.0
# 15607                                   716   320.0                 283.0
# 15610                                   734  1002.0                 932.0
# 15613                                   733   411.0                 207.0
# 15616                                   738   252.0                 218.0
# 15619                                   757   428.0                 108.0
# 15622                                   757   595.0                 230.0
# 15625                                   729   261.0                 247.0
# 15631                                   722   453.0                 381.0
# 15634                                   714  1010.0                 902.0
# 15640                                   726   972.0                 791.0
# 15643                                   730   858.0                 791.0
# 15646                                   738   796.0                 695.0
# 15649                                   736   948.0                 814.0
# 15652                                   761   461.0                 155.0
# 15655                                   715   654.0                 641.0
#
#        Free_Reduced_Lunch_%
# 4213                 0.6941
# 4216                 0.8364
# 4219                 0.8985
# 4222                 0.8303
# 4225                 0.9372
# 4228                 0.7116
# 4231                 0.5216
# 4234                 0.8976
# 4237                 0.9046
# 4240                 0.8908
# 4243                 0.8393
# 4246                 0.9126
# 4249                 0.6805
# 4252                 0.8527
# 4255                 0.8972
# 4258                 0.8137
# 4261                 0.9003
# 4264                 0.8873
# 4267                 0.8643
# 4270                 0.9362
# 4273                 0.9024
# 4276                 0.9000
# 4279                 0.7773
# 4282                 0.7822
# 4285                 0.9487
# 4288                 0.9326
# 4291                 0.8805
# 4294                 0.7930
# 4297                 0.6584
# 4300                 0.8958
# ...                     ...
# 15562                0.9250
# 15565                0.8605
# 15568                0.9211
# 15571                0.9654
# 15574                0.8221
# 15577                0.7978
# 15580                0.8513
# 15583                0.8196
# 15586                0.8618
# 15589                0.8861
# 15592                0.5748
# 15595                0.9844
# 15598                0.7509
# 15601                0.9642
# 15604                0.8210
# 15607                0.8844
# 15610                0.9301
# 15613                0.5036
# 15616                0.8651
# 15619                0.2523
# 15622                0.3866
# 15625                0.9464
# 15631                0.8411
# 15634                0.8931
# 15640                0.8138
# 15643                0.9219
# 15646                0.8731
# 15649                0.8586
# 15652                0.3362
# 15655                0.9801
#
# [862 rows x 7 columns]

# %%
sum_total_nonpilot_schools_2017=nonpilot_schools_selc3['Total'].sum()
print(sum_total_nonpilot_schools_2017)
# Out:
# 510669.0

# %%
sum_free_lunch_nonpilot_schools_2017=nonpilot_schools_selc3['Free_Reduced_Lunch_N'].sum()
print(sum_free_lunch_nonpilot_schools_2017)
# Out:
# 407134.0

# %%
avg_pecentage_select_nonpilot_schools=sum_free_lunch_nonpilot_schools_2017*100/sum_total_nonpilot_schools_2017
avg_pecentage_select_nonpilot_schools
# Out:
# 79.72561483074163

# %% [markdown]
# That's mean 79.72 % average percentage of students receive free/reduced lunch in the non-pilot schools in 2017

# %% [markdown]
# <h6>Conclusions</h6>

# %% [markdown]
# <h6>1- How did the pilot school 5th graders’ ELA mean scores compare to the non-pilot 5th graders in 2017 (2016 - 2017 school year)?</h6>
#
# <h5>1.1- What was the average score of all the pilot schools combined?</h5>
# <p>= 780.3 was the average score of the five pilot schools combined</p>
#
# <h5>1.2- What was the average score of all the non-pilot schools combined?</h5>
# <p>= 725.2 was the average score of all the non-pilot schools combined</p>
#
# <h6>2- Which pilot school exhibited the most growth in ELA mean scale scores?</h6>
#
# <h5>2.1- Which pilot school exhibited the most growth in ELA mean scale scores from the 2016 test through the 2017 test</h5>
# <p>= The school ID 610534 had the best performance ELA mean scale score 794.0</p>
#
# | Pilot_school_ID | ELA mean scale scores |
# |-----------------|:---------------------:|
# |      610534     |       794.0           |
# |      609880     |       791.5           |
# |      610066     |       779.0           |
# |      610082     |       771.0           |
# |      610182     |       766.0           |
# ![](Pilot Schools growth in ELA mean scale scores.png)
#
#
# <h5>2.2- What is the percentage difference in this school’s 5th grade growth from 2016 through 2017 compared to the other pilot schools’ 5th grade average growth during the same time period?</h5>
# <p>= The school ID 610534 has a percentage difference of 0.251. Concerning the other pilot schools, it didn't have a relevant change.</p>
#
# | Pilot_school_ID | Percentage difference 2016 & 2017 |
# |-----------------|:---------------------------------:|
# |      610534     |  0.251889                         |
# |      609880     |  0.126342                         |
# |      610066     |  1.797176                         |
# |      610082     |  0.77821                          |
# |      610182     |  0.522193                         |
#
#
#
# <h6>3- What was the average percentage of students who received free/reduced lunch in the five pilot schools in 2017?</h6>
# <p> In 2017, only 22% average percentage of students of pilot schools received free/reduced lunch</p>
#
# <h6>4- What was the average ELA mean test score of the non-pilot schools that have an equal or greater percentage of students who qualify for free/reduced lunch as the pilot schools? Only look at the 5th-grade class in the 2017 school year.</h6>
# <p> In 2017, 79.72 % average percentage of students of non pilot schools received free/reduced lunch</p>

# %% [markdown]
# <h6>Limitations</h6>

# %% [markdown]
# <p>Missing values-numerical values: Overall_ELA_Mean_Scale_Score column has several zeros values to handle. First, we replaced the zeros to NaN, later calculated the mean and reassigned this value to NaN, then we created new columns and dropped the initial columns with several zeros.</p>
#
# <p>Object type: We verified the object type to select the method to use; otherwise we got confused.<p>
